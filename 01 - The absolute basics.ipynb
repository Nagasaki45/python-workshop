# %% [markdown]
# # The absolute basics

# %% [markdown]
# The jupyter notebook: text cells and executable code cells.

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ## Comments

# %%
# This is a comment

# There is no such thing as multiple lines comments.
# Just add # in front of each line.

# %% [markdown]
# ## Names and values
#
# Lowercase letters with underscores

# %%
x = 1
x
# Out:
# 1

# %% [markdown]
# Name errors

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9063a9f0e032> in <module>()
# ----> 1 y
#
# NameError: name 'y' is not defined

# %% [markdown]
# *Note: always read the exception.*

# %% [markdown]
# ## Numbers
#
# `+, -, *, /, %, **, ()`

# %%
3 ** 2
# Out:
# 9

# %% [markdown]
# *Note: the result of division is always a float.*

# %%
3 / 2
# Out:
# 1.5

# %% [markdown]
# *Note: large numbers.*

# %%
# Out:
# ...

# %% [markdown]
# ## Booleans

# %%
False
# Out:
# False

# %% [markdown]
# `and`, `or`, and `not`

# %%
True or False
# Out:
# True

# %% [markdown]
# ## `None`

# %%
None

# %% [markdown]
# ## Strings
#
# Single / double quotes. Why?

# %%
"hello world" == 'hello world'
'He said "asdasd"'
# Out:
# 'He said "asdasd"'

# %% [markdown]
# `len`

# %%
len('hello world')
# Out:
# 11

# %% [markdown]
# `str` methods

# %%
s = 'hello world'
s.count()
# Out:
# True

# %% [markdown]
# The `in` operator

# %%
'z' in 'hello world'
# Out:
# False

# %% [markdown]
# *Note: functions vs. methods vs. operators*

# %% [markdown]
# Slicing

# %%
s
# Out:
# 'hello world'

# %%
s[::-1]
# Out:
# 'dlrow olleh'

# %% [markdown]
# String formatting with f-strings

# %%
name = 'Tom'
phd = 'MAT'

f"My name is {1 + 1}, I'm doing a phd in {phd}"
# Out:
# "My name is 2, I'm doing a phd in MAT"

# %% [markdown]
# *Note: [there are many ways to format a string](https://zerokspot.com/weblog/2015/12/31/new-string-formatting-in-python/)*

# %% [markdown]
# ## Casting
#
# `str`, `bool`, `int`, `float`

# %%
bool('0')
# Out:
# True

# %% [markdown]
# *Note: `None`, `0`, and empty strings/lists/dicts/tuples all evaluate to `False`, hence "falsy". All other values are "truthy".*

# %% [markdown]
# ## *Exercise*
#
# For me, the solution outputs the sentence `'My mother, Irit, was 24 years old when I was born'`. Change the variables and write the code to produce your version of the sentence.

# %%
# --- CHANGE THE VALUES ------ #
my_age = 29
my_mothers_age = 53
my_mothers_name = 'Irit'

# --- WRITE YOUR CODE HERE --- #

# ---------------------------- #
