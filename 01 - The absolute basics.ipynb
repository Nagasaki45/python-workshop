# %% [markdown]
# # The absolute basics

# %% [markdown]
# The jupyter notebook: text cells and executable code cells with output underneath.

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ## Comments

# %%
# This is a comment

# There is no such thing as multiple lines comments.
# Just add # in front of each line.

# %% [markdown]
# ## Names and values
#
# Lowercase letters with underscores

# %%
my_mame = 'Tom'

# %% [markdown]
# Name errors

# %%
your_name
# Out:
# --------------------------------------------------
# NameError        Traceback (most recent call last)
# <ipython-input-9-7add4b678118> in <module>
# ----> 1 your_name
#
# NameError: name 'your_name' is not defined

# %% [markdown]
# *Note: always read the exception.*

# %% [markdown]
# ## Numbers
#
# `+, -, *, /, %, **, ()`

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# *Note: the result of division is always a float.*

# %%
3 / 4
# Out:
# 0.75

# %% [markdown]
# *Note: large numbers.*

# %%
39 ** 8792
# Out:
# ...

# %% [markdown]
# ## Booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %% [markdown]
# `and`, `or`, and `not`

# %%
not False
# Out:
# True

# %% [markdown]
# ## `None`

# %%
None

# %% [markdown]
# ## Strings
#
# Single / double quotes. Why?

# %%
'my name is Tom'
# Out:
# 'my name is Tom'

# %%
"my name is Tom"
# Out:
# 'my name is Tom'

# %%
"What's your name?"
# Out:
# "What's your name?"

# %%
'She said: "No"'
# Out:
# 'She said: "No"'

# %% [markdown]
# `len`

# %%
len('my name is Tom')
# Out:
# 14

# %% [markdown]
# `str` methods

# %%
'my name is Tom'.capitalize()
# Out:
# 'My name is tom'

# %% [markdown]
# The `in` operator

# %%
'Tom' in 'my name is Tom'
# Out:
# True

# %% [markdown]
# *Note: functions vs. methods vs. operators*

# %% [markdown]
# Slicing

# %%
x = 'my name is TOM'
x[3:7]
# Out:
# 'name'

# %%
x = 'my name is TOM'
x[3:-3]
# Out:
# 'name is '

# %%
x = 'my name is TOM'
x[3:]
# Out:
# 'name is TOM'

# %%
x = 'my name is TOM'
x[:-4]
# Out:
# 'my name is'

# %%
x = 'my name is TOM'
x[1:8:2]  # 3rd argument is the jump
# Out:
# 'ynm '

# %%
x[::-1]  # General way to reverse 'things'
# Out:
# 'MOT si eman ym'

# %% [markdown]
# String interpolation

# %%
name = 'Sophie'
number = '074972391230'
f'dear {name}, we have lots of money for you. call us on {number}'
# Out:
# 'dear Sophie, we have lots of money for you. call us on 074972391230'

# %% [markdown]
# *Note: [there are many ways to format a string](https://zerokspot.com/weblog/2015/12/31/new-string-formatting-in-python/)*

# %%
len('קוראים לי תם')  # UNICODE!!!
# Out:
# 12

# %% [markdown]
# ## Casting
#
# `str`, `bool`, `int`, `float`

# %%
x = '20.2'
int(float(x))
# Out:
# 20

# %%
bool('0')
# Out:
# True

# %% [markdown]
# *Note: `None`, `0`, and empty strings/lists/dicts/tuples all evaluate to `False`, hence "falsy". All other values are "truthy".*

# %% [markdown]
# ## *Exercise*
#
# For me, the solution outputs the sentence `'My mother, Irit, was 24 years old when I was born'`. Change the variables and write the code to produce your version of the sentence.

# %%
# --- CHANGE THE VALUES ------ #
my_age = 30
my_mothers_age = 54
my_mothers_name = 'Irit'

# --- WRITE YOUR CODE HERE --- #

# ---------------------------- #
